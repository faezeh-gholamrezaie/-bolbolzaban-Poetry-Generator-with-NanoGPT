# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
with open('/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/train.txt') as f:
    chr_data = f.read()
    f.seek(0)
    lines = f.readlines()

print('length of characters: ', len(chr_data))
print('length of line: ', len(lines))
print(lines[0])
# Out:
# length of characters:  5772342
# length of line:  73027
# [CLS]فردوسی[CLS] [BOM] هم آنگه که بر تو بخواند دبیر [BOM] منه پیش و این را سگالش مگیر

# %%
# !pip -q install transformers

# %%
from transformers import AutoTokenizer
import torch

# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained("bolbolzaban/gpt2-persian")

# Add special tokens
#tokenizer.add_special_tokens({'pad_token': '[PAD]'})
#tokenizer.add_special_tokens({'eos_token': '[EOS]'})
#tokenizer.add_special_tokens({'bos_token': '[BOS]'})
#tokenizer.add_special_tokens({'cls_token': '[CLS]'})

# Define a function to tokenize data line by line
def tokenize_line_by_line(file_path, tokenizer, max_length = 25):
    tokenized_data = []
    with open(file_path, 'r') as f:
        for line in f:
            tokens = tokenizer(line.strip(), return_tensors="pt", truncation=True, max_length=max_length)
            tokenized_data.extend(tokens['input_ids'].squeeze().tolist())
    return tokenized_data

def decode(token_ids, tokenizer):
    return tokenizer.decode(token_ids, skip_special_tokens=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/537k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/399 [00:00<?, ?B/s]

# %%
# Path to your file
train_file_path = '/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/train.txt'

# Tokenize the entire data line by line
train_tokenized_data = tokenize_line_by_line(train_file_path, tokenizer)

print('First 128 tokens:', train_tokenized_data[:128])
print('Total number of tokens:', len(train_tokenized_data))
print(decode(train_tokenized_data[:128], tokenizer))
# Out:
# First 128 tokens: [5, 5, 4812, 5, 7, 83, 5349, 51, 64, 80, 5711, 1759, 7, 4743, 126, 45, 54, 53, 19696, 91, 11453, 3, 5, 5, 4812, 5, 7, 5400, 45, 244, 21905, 1248, 242, 7, 252, 1086, 128, 252, 105, 2547, 724, 3, 5, 5, 4812, 5, 7, 5400, 73, 7376, 150, 2122, 4482, 7, 161, 2122, 51, 9261, 2647, 48, 64, 3, 5, 5, 4812, 5, 7, 52, 692, 45, 64, 3340, 11441, 3335, 7, 120, 516, 252, 50, 6622, 72, 6622, 3, 5, 5, 4812, 5, 7, 9704, 72, 167, 21258, 7, 98, 939, 76, 53, 1542, 720, 3, 5, 5, 4812, 5, 7, 5403, 5963, 51, 57, 1603, 45, 562, 7, 105, 3537, 8874, 359, 252, 181, 2264, 3, 5, 5, 4812, 5, 7, 120, 21637]
# Total number of tokens: 1462244
# فردوسی هم آنگه که بر تو بخواند دبیر منه پیش و این را سگالش مگیر فردوسی برفت و بپیمود بالای شب پر اندیشه دل پر ز گفتار لب فردوسی برفتم بران شهر دیوان نر نه دیوان که شیران جنگی به بر فردوسی می آورد و برخواند رامشگران همه جام پر از کران تا کران فردوسی بفرمود تا راه نگذاشتند دو دستور او را نگه داشتند فردوسی فریدون فرخ که با داغ و درد ز گیتی بشد دیده پر آب زرد فردوسی همه سربسر

# %%
train_tokens = np.array(train_tokenized_data)
np.save('/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/Token/Bolbol_token_train.npy', train_tokens)

# %%
# Path to your file
val_file_path = '/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/test.txt'

# Tokenize the entire data line by line
val_tokenized_data = tokenize_line_by_line(val_file_path, tokenizer)

print('First 128 tokens:', val_tokenized_data[:128])
print('Total number of tokens:', len(val_tokenized_data))
print(decode(val_tokenized_data[:128], tokenizer))
# Out:
# First 128 tokens: [5, 5, 4812, 5, 7, 1702, 5130, 56, 50, 979, 45, 8713, 56, 7375, 7, 105, 80, 314, 74, 3669, 15036, 3, 5, 5, 4812, 5, 7, 136, 7582, 63, 127, 1663, 48, 9324, 7, 13234, 256, 64, 9324, 3305, 45, 18244, 3, 5, 5, 4812, 5, 7, 105, 1742, 45, 105, 6182, 52, 848, 65, 192, 7, 120, 572, 45, 144, 629, 2404, 2424, 3, 5, 5, 4812, 5, 7, 204, 54, 745, 60, 5243, 105, 80, 7, 2404, 724, 48, 1379, 9306, 73, 105, 80, 3, 5, 5, 4812, 5, 7, 5400, 2559, 4591, 2562, 80, 476, 7, 48, 221, 2109, 1745, 877, 80, 476, 3, 5, 5, 4812, 5, 7, 204, 5385, 74, 1222, 244, 20812, 880, 7, 67, 45, 303, 9746, 2298, 6632, 3]
# Total number of tokens: 76985
# فردوسی رهاگشتی از بند و رستی بجان ز تو دور شد کینه بدگمان فردوسی بیندود یک روی آهن به قیر پراگند بر قیر مشک و عبیر فردوسی ز خورد و ز بخشش میاسای هیچ همه دانش و داد دادن بسیچ فردوسی چو این داستانها شنیدم ز تو بسی لب به دندان گزیدم ز تو فردوسی برفتنت یزدان پناه تو باد به باز آمدن تخت گاه تو باد فردوسی چو آسوده شد زین بشادی نشست خود و جنگسازان خسرو پرست

# %%
val_tokens = np.array(val_tokenized_data)
np.save('/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/Token/Bolbol_token_test.npy', val_tokens)

# %% [markdown]
# #NanoGPT

# %%
import os
import math
import time
import inspect
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.nn import functional as F
#from hellaswag import render_example, iterate_examples
# -----------------------------------------------------------------------------

class CausalSelfAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1
        # regularization
        self.n_head = config.n_head
        self.n_embd = config.n_embd

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)
        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        # nh is "number of heads", hs is "head size", and C (number of channels) = nh * hs
        # e.g. in GPT-2 (124M), n_head=12, hs=64, so nh*hs=C=768 channels in the Transformer
        qkv = self.c_attn(x)
        q, k, v = qkv.split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        y = F.scaled_dot_product_attention(q, k, v, is_causal=True) # flash attention
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side
        # output projection
        y = self.c_proj(y)
        return y

class MLP(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd)
        self.gelu    = nn.GELU(approximate='tanh')
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

@dataclass
class GPTConfig:
    block_size: int = 1024 # max sequence length
    vocab_size: int = 50257 # number of tokens: 50,000 BPE merges + 256 bytes tokens + 1 <|endoftext|> token
    n_layer: int = 12 # number of layers
    n_head: int = 12 # number of heads
    n_embd: int = 768 # embedding dimension

class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = nn.LayerNorm(config.n_embd),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

        # weight sharing scheme
        self.transformer.wte.weight = self.lm_head.weight

        # init params
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            std = 0.02
            if hasattr(module, 'NANOGPT_SCALE_INIT'):
                std *= (2 * self.config.n_layer) ** -0.5
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        # idx is of shape (B, T)
        B, T = idx.size()
        assert T <= self.config.block_size, f"Cannot forward sequence of length {T}, block size is only {self.config.block_size}"
        # forward the token and posisition embeddings
        pos = torch.arange(0, T, dtype=torch.long, device=idx.device) # shape (T)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (T, n_embd)
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (B, T, n_embd)
        x = tok_emb + pos_emb
        # forward the blocks of the transformer
        for block in self.transformer.h:
            x = block(x)
        # forward the final layernorm and the classifier
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x) # (B, T, vocab_size)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
        return logits, loss

    @classmethod
    def from_pretrained(cls, model_type):
        """Loads pretrained GPT-2 model weights from huggingface"""
        assert model_type in {'gpt2', 'gpt2-medium', 'gpt2-large', 'gpt2-xl'}
        from transformers import GPT2LMHeadModel
        print("loading weights from pretrained gpt: %s" % model_type)

        # n_layer, n_head and n_embd are determined from model_type
        config_args = {
            'gpt2':         dict(n_layer=12, n_head=12, n_embd=768),  # 124M params
            'gpt2-medium':  dict(n_layer=24, n_head=16, n_embd=1024), # 350M params
            'gpt2-large':   dict(n_layer=36, n_head=20, n_embd=1280), # 774M params
            'gpt2-xl':      dict(n_layer=48, n_head=25, n_embd=1600), # 1558M params
        }[model_type]
        config_args['vocab_size'] = 50257 # always 50257 for GPT model checkpoints
        config_args['block_size'] = 1024 # always 1024 for GPT model checkpoints
        # create a from-scratch initialized minGPT model
        config = GPTConfig(**config_args)
        model = GPT(config)
        sd = model.state_dict()
        sd_keys = sd.keys()
        sd_keys = [k for k in sd_keys if not k.endswith('.attn.bias')] # discard this mask / buffer, not a param

        # init a huggingface/transformers model
        model_hf = GPT2LMHeadModel.from_pretrained(model_type)
        sd_hf = model_hf.state_dict()

        # copy while ensuring all of the parameters are aligned and match in names and shapes
        sd_keys_hf = sd_hf.keys()
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.masked_bias')] # ignore these, just a buffer
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.bias')] # same, just the mask (buffer)
        transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
        # basically the openai checkpoints use a "Conv1D" module, but we only want to use a vanilla Linear
        # this means that we have to transpose these weights when we import them
        assert len(sd_keys_hf) == len(sd_keys), f"mismatched keys: {len(sd_keys_hf)} != {len(sd_keys)}"
        for k in sd_keys_hf:
            if any(k.endswith(w) for w in transposed):
                # special treatment for the Conv1D weights we need to transpose
                assert sd_hf[k].shape[::-1] == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k].t())
            else:
                # vanilla copy over the other parameters
                assert sd_hf[k].shape == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k])

        return model

    def configure_optimizers(self, weight_decay, learning_rate, device_type):
        # start with all of the candidate parameters (that require grad)
        param_dict = {pn: p for pn, p in self.named_parameters()}
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        if master_process:
            print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
            print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == "cuda"
        if master_process:
            print(f"using fused AdamW: {use_fused}")
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=(0.9, 0.95), eps=1e-8, fused=use_fused)
        return optimizer

# -----------------------------------------------------------------------------
#import tiktoken
import numpy as np

def load_tokens(filename):
    npt = np.load(filename)
    npt = npt.astype(np.int32) # added after video
    ptt = torch.tensor(npt, dtype=torch.long)
    return ptt



class DataLoaderLite:
    def __init__(self, B, T, process_rank, num_processes, split):
        self.B = B
        self.T = T
        self.process_rank = process_rank
        self.num_processes = num_processes
        assert split in {'train', 'test'}

        # get the shard filenames
        data_root = "/content/drive/MyDrive/Colab Notebooks/GenAI/Bolbol_Data/Token"
        shards = os.listdir(data_root)
        shards = [s for s in shards if split in s]
        shards = sorted(shards)
        shards = [os.path.join(data_root, s) for s in shards]
        self.shards = shards
        assert len(shards) > 0, f"no shards found for split {split}"
        if master_process:
            print(f"found {len(shards)} shards for split {split}")
        self.reset()

    def reset(self):
        # state, init at shard zero
        self.current_shard = 0
        self.tokens = load_tokens(self.shards[self.current_shard])
        self.current_position = self.B * self.T * self.process_rank

    def next_batch(self):
        B, T = self.B, self.T
        buf = self.tokens[self.current_position : self.current_position+B*T+1]
        x = (buf[:-1]).view(B, T) # inputs
        y = (buf[1:]).view(B, T) # targets
        # advance the position in the tensor
        self.current_position += B * T * self.num_processes
        # if loading the next batch would be out of bounds, advance to next shard
        if self.current_position + (B * T * self.num_processes + 1) > len(self.tokens):
            self.current_shard = (self.current_shard + 1) % len(self.shards)
            self.tokens = load_tokens(self.shards[self.current_shard])
            self.current_position = B * T * self.process_rank
        return x, y


# -----------------------------------------------------------------------------
# helper function for HellaSwag eval
# takes tokens, mask, and logits, returns the index of the completion with the lowest loss

def get_most_likely_row(tokens, mask, logits):
    # evaluate the autoregressive loss at all positions
    shift_logits = (logits[..., :-1, :]).contiguous()
    shift_tokens = (tokens[..., 1:]).contiguous()
    flat_shift_logits = shift_logits.view(-1, shift_logits.size(-1))
    flat_shift_tokens = shift_tokens.view(-1)
    shift_losses = F.cross_entropy(flat_shift_logits, flat_shift_tokens, reduction='none')
    shift_losses = shift_losses.view(tokens.size(0), -1)
    # now get the average loss just for the completion region (where mask == 1), in each row
    shift_mask = (mask[..., 1:]).contiguous() # we must shift mask, so we start at the last prompt token
    masked_shift_losses = shift_losses * shift_mask
    # sum and divide by the number of 1s in the mask
    sum_loss = masked_shift_losses.sum(dim=1)
    avg_loss = sum_loss / shift_mask.sum(dim=1)
    # now we have a loss for each of the 4 completions
    # the one with the lowest loss should be the most likely
    pred_norm = avg_loss.argmin().item()
    return pred_norm

# -----------------------------------------------------------------------------
# simple launch:
# python train_gpt2.py
# DDP launch for e.g. 8 GPUs:
# torchrun --standalone --nproc_per_node=8 train_gpt2.py

# run the training loop
from torch.distributed import init_process_group, destroy_process_group
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.distributed as dist

# set up DDP (distributed data parallel).
# torchrun command sets the env variables RANK, LOCAL_RANK, and WORLD_SIZE
ddp = int(os.environ.get('RANK', -1)) != -1 # is this a ddp run?
if ddp:
    # use of DDP atm demands CUDA, we set the device appropriately according to rank
    assert torch.cuda.is_available(), "for now i think we need CUDA for DDP"
    init_process_group(backend='nccl')
    ddp_rank = int(os.environ['RANK'])
    ddp_local_rank = int(os.environ['LOCAL_RANK'])
    ddp_world_size = int(os.environ['WORLD_SIZE'])
    device = f'cuda:{ddp_local_rank}'
    torch.cuda.set_device(device)
    master_process = ddp_rank == 0 # this process will do logging, checkpointing etc.
else:
    # vanilla, non-DDP run
    ddp_rank = 0
    ddp_local_rank = 0
    ddp_world_size = 1
    master_process = True
    # attempt to autodetect device
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
        device = "mps"
    print(f"using device: {device}")

# added after video, pytorch can be serious about it's device vs. device_type distinction
device_type = "cuda" if device.startswith("cuda") else "cpu"

torch.manual_seed(1337)
if torch.cuda.is_available():
    torch.cuda.manual_seed(1337)


total_batch_size = 18432 # 2**19, ~0.5M, in number of tokens
B = 4 # micro batch size
T = 512 # sequence length
assert total_batch_size % (B * T * ddp_world_size) == 0, "make sure total_batch_size is divisible by B * T * ddp_world_size"
grad_accum_steps = total_batch_size // (B * T * ddp_world_size)
if master_process:
    print(f"total desired batch size: {total_batch_size}")
    print(f"=> calculated gradient accumulation steps: {grad_accum_steps}")

train_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, split="train")
val_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, split="test")

torch.set_float32_matmul_precision('high')

# create model
model = GPT(GPTConfig(vocab_size=50304))
# model = GPT.from_pretrained("gpt2") # or init from OpenAI GPT-2
model.to(device)
use_compile = False # torch.compile interferes with HellaSwag eval and Generation. TODO fix
if use_compile:
    model = torch.compile(model)
if ddp:
    model = DDP(model, device_ids=[ddp_local_rank])
raw_model = model.module if ddp else model # always contains the "raw" unwrapped model

max_lr = 6e-4
min_lr = max_lr * 0.1
warmup_steps = 715
max_steps = 129 # 19,073 steps is ~1 epoch, if data is 10B tokens and batch size 0.5M tokens
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_steps:
        return max_lr * (it+1) / warmup_steps
    # 2) if it > lr_decay_iters, return min learning rate
    if it > max_steps:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_steps) / (max_steps - warmup_steps)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff starts at 1 and goes to 0
    return min_lr + coeff * (max_lr - min_lr)

# optimize!
optimizer = raw_model.configure_optimizers(weight_decay=0.1, learning_rate=6e-4, device_type=device_type)

# create the log directory we will write checkpoints to and log to
log_dir = "log"
os.makedirs(log_dir, exist_ok=True)
log_file = os.path.join(log_dir, f"log.txt")
with open(log_file, "w") as f: # open for writing to clear the file
    pass

for step in range(max_steps):
    t0 = time.time()
    last_step = (step == max_steps - 1)

    # once in a while evaluate our validation loss
    if step % 250 == 0 or last_step:
        model.eval()
        val_loader.reset()
        with torch.no_grad():
            val_loss_accum = 0.0
            val_loss_steps = 20
            for _ in range(val_loss_steps):
                x, y = val_loader.next_batch()
                x, y = x.to(device), y.to(device)
                with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                    logits, loss = model(x, y)
                loss = loss / val_loss_steps
                val_loss_accum += loss.detach()
        if ddp:
            dist.all_reduce(val_loss_accum, op=dist.ReduceOp.AVG)
        if master_process:
            print(f"validation loss: {val_loss_accum.item():.4f}")
            with open(log_file, "a") as f:
                f.write(f"{step} val {val_loss_accum.item():.4f}\n")
            if step > 0 and (step % 5000 == 0 or last_step):
                # optionally write model checkpoints
                checkpoint_path = os.path.join(log_dir, f"model_{step:05d}.pt")
                checkpoint = {
                    'model': raw_model.state_dict(),
                    'config': raw_model.config,
                    'step': step,
                    'val_loss': val_loss_accum.item()
                }
                # you might also want to add optimizer.state_dict() and
                # rng seeds etc., if you wanted to more exactly resume training
                torch.save(checkpoint, checkpoint_path)

################################################################################

    # once in a while generate from the model (except step 0, which is noise)
    if ((step > 0) or last_step) and (not use_compile):
        model.eval()
        num_return_sequences = 4
        max_length = 32
        tokens = tokenizer.encode("بهار دلکش")
        tokens = torch.tensor(tokens, dtype=torch.long)
        tokens = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
        xgen = tokens.to(device)
        sample_rng = torch.Generator(device=device)
        sample_rng.manual_seed(42 + ddp_rank)
        while xgen.size(1) < max_length:
            # forward the model to get the logits
            with torch.no_grad():
                with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                    logits, loss = model(xgen) # (B, T, vocab_size)
                # take the logits at the last position
                logits = logits[:, -1, :] # (B, vocab_size)
                # get the probabilities
                probs = F.softmax(logits, dim=-1)
                # do top-k sampling of 50 (huggingface pipeline default)
                # topk_probs here becomes (5, 50), topk_indices is (5, 50)
                topk_probs, topk_indices = torch.topk(probs, 50, dim=-1)
                # select a token from the top-k probabilities
                # note: multinomial does not demand the input to sum to 1
                ix = torch.multinomial(topk_probs, 1, generator=sample_rng) # (B, 1)
                # gather the corresponding indices
                xcol = torch.gather(topk_indices, -1, ix) # (B, 1)
                # append to the sequence
                xgen = torch.cat((xgen, xcol), dim=1)
        # print the generated text
        for i in range(num_return_sequences):
            tokens = xgen[i, :max_length].tolist()
            decoded = tokenizer.decode(tokens)
            print(f"rank {ddp_rank} sample {i}: {decoded}")

    # do one step of the optimization
    model.train()
    optimizer.zero_grad()
    loss_accum = 0.0
    for micro_step in range(grad_accum_steps):
        x, y = train_loader.next_batch()
        x, y = x.to(device), y.to(device)
        # added after video, this field is also used by the forward pass.
        if ddp:
            model.require_backward_grad_sync = (micro_step == grad_accum_steps - 1)
        with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
            logits, loss = model(x, y)
        # we have to scale the loss to account for gradient accumulation,
        # because the gradients just add on each successive backward().
        # addition of gradients corresponds to a SUM in the objective, but
        # instead of a SUM we want MEAN. Scale the loss here so it comes out right
        loss = loss / grad_accum_steps
        loss_accum += loss.detach()
        loss.backward()
    if ddp:
        dist.all_reduce(loss_accum, op=dist.ReduceOp.AVG)
    norm = torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    # determine and set the learning rate for this iteration
    lr = get_lr(step)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    optimizer.step()
    if device_type == "cuda":
        torch.cuda.synchronize() # wait for the GPU to finish work
    t1 = time.time()
    dt = t1 - t0 # time difference in seconds
    tokens_processed = train_loader.B * train_loader.T * grad_accum_steps * ddp_world_size
    tokens_per_sec = tokens_processed / dt
    if master_process:
        print(f"step {step:5d} | loss: {loss_accum.item():.6f} | lr {lr:.4e} | norm: {norm:.4f} | dt: {dt*1000:.2f}ms | tok/sec: {tokens_per_sec:.2f}")
        with open(log_file, "a") as f:
            f.write(f"{step} train {loss_accum.item():.6f}\n")

if ddp:
    destroy_process_group()
# Out:
# using device: cuda
# total desired batch size: 18432
# => calculated gradient accumulation steps: 9
# found 1 shards for split train
# found 1 shards for split test
# num decayed parameter tensors: 50, with 124,354,560 parameters
# num non-decayed parameter tensors: 98, with 121,344 parameters
# using fused AdamW: True
# validation loss: 10.8957
# step     0 | loss: 10.898790 | lr 8.3916e-07 | norm: 36.5815 | dt: 11000.91ms | tok/sec: 1675.50
# rank 0 sample 0: [CLS] بهار دلکش[SEP] نمودیم نمودیم ترزابرادر افزود دالاهو هندبال قفسه مشت مهرگان نتوانستیم هاوس لرز چنار سرودی حدودی سرکار موکلم مستندات
# rank 0 sample 1: [CLS] بهار دلکش[SEP] متبلور آفتاب سرودی گرایانهوک راهنمایی هرودوت غمناک
# rank 0 sample 2: [CLS] بهار دلکش[SEP] علیها آهنگسازان دربردارنده اسیدی اپیزود نتوانستیم آشپز ایستادن دمپایی دمپایی غمناک بشکن بدرود تراکت کیبورد منظور سربر
# rank 0 sample 3: [CLS] بهار دلکش[SEP]الامر فداکارخلف دبستانی اد نایلون عمویش آدو پرکردن اینستا ناسیونالیسم دمپایی دمپایی سربر افگارویچ
# step     1 | loss: 10.775940 | lr 1.6783e-06 | norm: 35.9602 | dt: 6573.87ms | tok/sec: 2803.83
# rank 0 sample 0: [CLS] بهار دلکش[SEP]ینی حنا افزود میمیره ترزا جوایزیراناخطاره تاسف جوایز مطلقه زهر نشنیدمیراناکین مخ
# rank 0 sample 1: [CLS] بهار دلکش[SEP] ضابط سرودی قدت بینا ضابط صبوحی آشیل کرنر سکه کشو
# rank 0 sample 2: [CLS] بهار دلکش[SEP]بودند همتای کارگاههای توانا عشایر مطلقه برگهانیه حراج جوایز دیدنپارد مق
# rank 0 sample 3: [CLS] بهار دلکش[SEP]کانچه صلیبی ایستادناکین همنشین محمدحسن مجسمه رسد صدهزار شول ئی
# step     2 | loss: 10.550181 | lr 2.5175e-06 | norm: 34.2765 | dt: 6275.68ms | tok/sec: 2937.05
# rank 0 sample 0: [CLS] بهار دلکش[SEP] بلیت هرودوت نایلون حراج کارگیری بیدار حکایات نشنیدم بنزما گواهی عمویش پروم[BOM] سفری رحیمی حقوقدانان
# rank 0 sample 1: [CLS] بهار دلکش[SEP] روءسای لوزالمعده فقط روءسای رشادت صنعتی خودنمایی اعراب آموزشی میمیره[BOM] بوده نفیر عمویش خودنمایی سفری میمیره ناراضی تست
# rank 0 sample 2: [CLS] بهار دلکش[SEP] حکایات نپذیرفت اوایلتاون لرستان دماسنج دالاس افزود بوئیننیه دبستانی صیادی محمدحسن یکتا مق
# rank 0 sample 3: [CLS] بهار دلکش[SEP] حقیقت استثنای استثنای غمناک هر استعلام مطلقه[BOM] کینه تدریج نایلون دیتا تجریشتابی گشودند شول شول
# step     3 | loss: 10.238043 | lr 3.3566e-06 | norm: 30.4895 | dt: 6328.58ms | tok/sec: 2912.50
# rank 0 sample 0: [CLS] بهار دلکش[SEP] آفتاب آفتابنیه دلفین مطلقه وسائل[CLS] سپرد[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP]۴ هبوط الاب اسلاف غمناک صریحا صنعتییران[BOM] بوده آمیزی مقدک رشادت فقها گردهمائی[BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP] احیاء ضابط حقیقت اعتصاباتنیه چادر شعور درسال اعراب[BOM] بقول مجسمه فرارسیدن غمناک دلفین[BOM] آلومینیمپرست عمویش تعصب
# rank 0 sample 3: [CLS] بهار دلکش[SEP][BOM] دوبله[BOM][BOM] ایستادن رویه سپر حل فولکس لحظه ناراحت وابستگان[CLS][BOM]
# step     4 | loss: 9.882142 | lr 4.1958e-06 | norm: 25.5211 | dt: 6383.46ms | tok/sec: 2887.46
# rank 0 sample 0: [CLS] بهار دلکش[SEP] الاب[CLS] نایلون[CLS]اکینتاون[BOM]ینی[CLS] گرایانه بلوچ[CLS]ینید[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP] پیت[CLS][CLS][CLS] تأثیرگذاری صابری تأثیرگذاری[BOM]نیه[BOM] کارگیری غمناک[CLS][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM][CLS]ادور[BOM] نایلون کارگیری[CLS][CLS] کارگیری[CLS] بقول[CLS][BOM][BOM][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP] احیاء بکمال بکمال[CLS][CLS][BOM][BOM] الشیطان فردوسی[RES14]اوبرای فردوسی کارگیری برشمرده[BOM][CLS][BOM]
# step     5 | loss: 9.549273 | lr 5.0350e-06 | norm: 21.1681 | dt: 6534.11ms | tok/sec: 2820.89
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM]نیه اعراب فردوسی[CLS] حومه[BOM] عمویش عمویش[CLS][BOM] دلفین دلفین[BOM][CLS] بیارم[CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP] پیت اعراب[CLS][CLS][CLS] لیس[CLS] دلفین تأثیرگذاری[BOM] دوبله[CLS][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM] رسد نساخت[CLS] اعرابواج[CLS] بکمالینی[CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM] پاشایی[CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][CLS][CLS][BOM] دلفین[BOM][CLS][CLS][CLS][CLS][CLS] کرگدن رشادت[BOM] دالاس شیرین[CLS][BOM][CLS][CLS]
# step     6 | loss: 9.251688 | lr 5.8741e-06 | norm: 17.9516 | dt: 6514.42ms | tok/sec: 2829.42
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][BOM] موریس[CLS][BOM][BOM][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP] گمگشته[CLS][CLS][CLS][CLS][BOM][CLS] فردوسی موریس[BOM][CLS] شاهانه[CLS][CLS][CLS][CLS][BOM] تعقیب[CLS][CLS][CLS][CLS][CLS][BOM][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][CLS] الشیطان تست[CLS] احیاء[CLS][CLS][CLS]ینی[CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][CLS][BOM][CLS][BOM] جانبازی[CLS][CLS][CLS][CLS][CLS][CLS] سالمند[CLS][CLS][BOM][CLS][CLS][CLS][BOM][CLS][CLS]
# step     7 | loss: 8.977210 | lr 6.7133e-06 | norm: 15.1386 | dt: 6589.67ms | tok/sec: 2797.11
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS] فردوسی ([BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM] موریس[CLS][CLS][CLS][CLS][CLS][BOM][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS] ([CLS][CLS] جشن[CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] برپاست[CLS][CLS][CLS][CLS][BOM][CLS][BOM] و[CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][CLS]
# step     8 | loss: 8.759944 | lr 7.5524e-06 | norm: 12.4894 | dt: 6658.45ms | tok/sec: 2768.21
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS] ماهیچه[CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][BOM] صور[CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][CLS]
# step     9 | loss: 8.570959 | lr 8.3916e-06 | norm: 10.3341 | dt: 6731.01ms | tok/sec: 2738.37
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][CLS][CLS][BOM] شاهباز[CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][BOM]پرداز[CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][CLS]
# step    10 | loss: 8.404074 | lr 9.2308e-06 | norm: 8.9608 | dt: 6776.01ms | tok/sec: 2720.18
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][CLS][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][BOM][BOM][BOM][CLS][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][BOM][BOM][CLS][CLS][CLS][CLS][BOM][CLS] فردوسی شهدای[CLS][BOM][CLS][CLS][CLS][BOM][SEP][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][BOM][CLS][CLS][CLS][BOM][BOM][CLS][CLS][BOM][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS][CLS]
# step    11 | loss: 8.279336 | lr 1.0070e-05 | norm: 7.4980 | dt: 6884.54ms | tok/sec: 2677.30
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][BOM][BOM][BOM][CLS][BOM][CLS][CLS][BOM][CLS][BOM][CLS][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][SEP] چطور[CLS][BOM][BOM][BOM][CLS][BOM][SEP][CLS][BOM][CLS][BOM][BOM][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM] بریتانیائی[BOM][BOM][BOM][CLS][BOM][BOM][BOM][CLS][CLS][BOM][BOM][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][BOM][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][CLS][CLS][BOM][BOM][CLS] به[CLS][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][CLS][CLS][BOM]ذار[CLS][BOM][CLS][CLS]
# step    12 | loss: 8.169971 | lr 1.0909e-05 | norm: 7.0598 | dt: 6947.11ms | tok/sec: 2653.19
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][BOM][BOM][CLS][BOM][BOM][BOM][CLS][CLS][BOM][CLS][BOM][SEP][BOM][BOM][BOM][BOM][BOM][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][BOM][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][SEP][CLS][BOM][BOM][BOM][BOM][BOM][SEP][CLS][BOM][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM]شمارند[BOM][BOM][BOM][BOM][CLS][CLS][CLS][BOM][BOM][BOM][BOM][BOM][CLS][BOM][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][BOM][BOM][CLS][CLS][BOM]شمارند[CLS][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][SEP][CLS][BOM][CLS][BOM]
# step    13 | loss: 8.061822 | lr 1.1748e-05 | norm: 6.8431 | dt: 7073.69ms | tok/sec: 2605.71
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][BOM][BOM][CLS][BOM][CLS][SEP][CLS][CLS][BOM][BOM][BOM][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][CLS][CLS][CLS][BOM]ش[BOM][SEP][CLS][CLS][BOM][BOM][BOM][CLS][BOM][SEP][CLS][BOM][CLS][BOM][BOM][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM]ئیم[BOM][CLS][CLS][BOM][CLS][CLS][CLS][BOM][BOM] که[BOM][BOM][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][BOM][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][SEP][CLS][BOM][CLS][BOM]
# step    14 | loss: 7.958248 | lr 1.2587e-05 | norm: 6.1234 | dt: 7126.29ms | tok/sec: 2586.48
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS][CLS][CLS][BOM][BOM][CLS][BOM][CLS][SEP][CLS][CLS][BOM][BOM][BOM][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][CLS][CLS][CLS][CLS][CLS][BOM][BOM][SEP][CLS][CLS][BOM][BOM][SEP][CLS][BOM][SEP][CLS][BOM][CLS][BOM][BOM][CLS][CLS][CLS][BOM][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM][BOM][CLS][CLS][BOM][BOM][BOM] ساتیا[CLS][CLS] به[BOM][BOM][CLS][CLS][BOM][BOM][CLS][CLS][CLS][BOM][BOM][CLS][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][SEP] فردی[CLS][BOM][CLS][BOM]
# step    15 | loss: 7.882741 | lr 1.3427e-05 | norm: 6.0918 | dt: 7169.70ms | tok/sec: 2570.82
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][BOM][CLS][BOM][SEP][CLS][BOM][BOM][CLS][BOM][CLS] فردوسی[CLS][BOM][SEP][CLS][CLS][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][BOM][SEP][CLS][CLS][BOM][BOM][SEP][CLS][CLS][BOM][BOM][SEP][CLS][BOM][SEP][CLS][BOM][BOM][CLS][BOM][SEP][CLS][CLS][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][BOM][BOM] رشادت[BOM][BOM][BOM][BOM][BOM][BOM] کج[BOM][CLS]ئیم[BOM][BOM][CLS][CLS][BOM][CLS][CLS][CLS][CLS][BOM][BOM][BOM][CLS][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][CLS][BOM][BOM][BOM][CLS][CLS][CLS][CLS][CLS][BOM][CLS][BOM][SEP][CLS][BOM][BOM][CLS][CLS][BOM][SEP] دلفین[CLS][BOM][BOM][BOM]
# step    16 | loss: 7.785499 | lr 1.4266e-05 | norm: 5.8937 | dt: 7065.46ms | tok/sec: 2608.75
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM] فردوسی[CLS][CLS][BOM][CLS] فردوسی[CLS][BOM][CLS][BOM][BOM][SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][CLS][BOM][SEP][CLS][BOM][CLS][BOM][SEP][CLS][BOM][BOM][CLS] فردوسی[CLS][CLS][BOM][BOM][BOM][CLS][BOM][BOM][SEP][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM]شمس[SEP][CLS][BOM][BOM][SEP][CLS][BOM][BOM][BOM] شاهنامه[BOM][BOM][BOM][BOM][CLS][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][CLS] نشنیدم[BOM][BOM][BOM][BOM][BOM][SEP][CLS][BOM][BOM][SEP][CLS][BOM][CLS] از[CLS][CLS][BOM][BOM]
# step    17 | loss: 7.685071 | lr 1.5105e-05 | norm: 5.7906 | dt: 6975.53ms | tok/sec: 2642.38
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM]شمارند[BOM][BOM][SEP][CLS][BOM][BOM][SEP][CLS][CLS][BOM][SEP][CLS][CLS][BOM][CLS][BOM][BOM][SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][CLS][BOM][SEP][CLS][BOM][CLS][BOM][SEP][CLS][BOM][BOM][SEP][CLS][BOM][SEP][CLS][BOM][BOM][BOM][BOM][BOM][SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM] شاهنامه[SEP][CLS][BOM][BOM][SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][CLS] سفارش[BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][SEP][CLS][BOM][CLS][BOM][SEP][CLS][BOM]
# step    18 | loss: 7.608904 | lr 1.5944e-05 | norm: 5.2844 | dt: 6910.68ms | tok/sec: 2667.17
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM] تابو[BOM][BOM][SEP][CLS][BOM][SEP][CLS][CLS][BOM] به و[SEP][CLS] فردوسی[CLS][BOM][SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][BOM][BOM][BOM] بارگذاری[BOM] و ز کیل[SEP][CLS][BOM] به[BOM] و[BOM][BOM] و[SEP][CLS][BOM][SEP][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] اسکان[CLS][BOM][BOM][SEP][CLS][BOM] کج[BOM][BOM] شاهنامه[BOM][SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS][CLS][CLS][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][SEP][CLS][BOM][CLS][BOM][BOM][SEP][CLS][BOM] و کفن[BOM][BOM][SEP][CLS]
# step    19 | loss: 7.509109 | lr 1.6783e-05 | norm: 4.7658 | dt: 6867.14ms | tok/sec: 2684.09
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM][BOM][BOM][BOM] کیل[SEP][CLS][CLS][CLS][BOM] از و[SEP][CLS] فردوسی[CLS][BOM][BOM][SEP]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][BOM]رند[SEP][CLS]نیتس[BOM][SEP][CLS][BOM] به[BOM] و[BOM][SEP][CLS][CLS][BOM][SEP][CLS][BOM][SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS][BOM] بپرسم[BOM][BOM] با[BOM][BOM][SEP][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][BOM] و[SEP][CLS][BOM][SEP][CLS][CLS][BOM] و[BOM][BOM][SEP][CLS][BOM] و ساتیا[BOM][BOM][SEP][CLS]
# step    20 | loss: 7.450825 | lr 1.7622e-05 | norm: 4.2827 | dt: 6848.56ms | tok/sec: 2691.37
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM][SEP][CLS][CLS][BOM][SEP][CLS][CLS][BOM] ز[BOM][SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM] و فابیو[BOM][SEP][CLS][BOM] که[BOM] و[BOM][SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] فردا[BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM] با[BOM][BOM][SEP][CLS][CLS][BOM][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][SEP][CLS][BOM] و بارگذاری[BOM][BOM][SEP][CLS]
# step    21 | loss: 7.377797 | lr 1.8462e-05 | norm: 3.7488 | dt: 6829.88ms | tok/sec: 2698.73
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM] کیل[BOM][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM] که و[SEP][CLS] فردوسی[CLS][BOM][BOM][SEP]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM] و[BOM][SEP][CLS][BOM] که[BOM] و[BOM][SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][BOM][BOM][BOM][SEP][CLS][BOM][SEP][CLS][CLS][BOM][BOM][BOM][SEP][CLS][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][SEP][CLS][BOM] و[SEP][CLS][BOM][BOM]
# step    22 | loss: 7.338822 | lr 1.9301e-05 | norm: 3.5304 | dt: 6846.43ms | tok/sec: 2692.21
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM]شمارند[BOM][BOM][BOM][BOM][SEP][CLS][BOM][BOM][BOM] که و[BOM][SEP][CLS][BOM][SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM] و[BOM][SEP][CLS][BOM] که[BOM] و[BOM][SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] نیازی[SEP][CLS][CLS][BOM][SEP][CLS][BOM][BOM][BOM] بر[SEP][CLS][CLS][BOM][SEP][CLS][BOM][BOM][BOM][BOM][BOM][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][SEP][CLS][BOM] و[SEP][CLS][BOM][BOM]
# step    23 | loss: 7.287400 | lr 2.0140e-05 | norm: 3.2607 | dt: 6902.17ms | tok/sec: 2670.46
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM][SEP][CLS][BOM][SEP][CLS][BOM] ز[BOM] که[SEP][CLS] فردوسی[CLS][BOM] ز[BOM][SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS][BOM] و[BOM][SEP][CLS][BOM] که[BOM] و[BOM][SEP][CLS][BOM][SEP][CLS][BOM][SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بیسیم[BOM][BOM][SEP][CLS][BOM]شمس[BOM][SEP][CLS][CLS][BOM][BOM][BOM][SEP][CLS][BOM][SEP][CLS][CLS][CLS][BOM][BOM][BOM] ز
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM][BOM][BOM][SEP][CLS] فردوسی[CLS][BOM] ز[SEP][CLS][BOM] و بارگذاری[BOM][BOM][SEP][CLS]
# step    24 | loss: 7.219142 | lr 2.0979e-05 | norm: 3.0905 | dt: 6928.32ms | tok/sec: 2660.38
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM][SEP][CLS][BOM][BOM] کرد[BOM][BOM][BOM] بهشمس[SEP][CLS][BOM] که[SEP][CLS] فردوسی[CLS][BOM] ز[BOM][SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM] و[BOM] به ذیصلاح[BOM] بهالات[SEP][CLS][BOM][BOM] که[BOM] به[SEP][CLS][BOM] و[SEP][CLS][BOM] و[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM]الات[SEP][CLS][CLS][BOM] از[BOM][BOM][BOM] بر[SEP][CLS][CLS][BOM][SEP][CLS][BOM][BOM][BOM][BOM][BOM][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][BOM] و[SEP][CLS][BOM][SEP][CLS][BOM] از و بهشهر[BOM] ز[SEP][CLS][BOM] به[BOM][BOM][BOM] و
# step    25 | loss: 7.183989 | lr 2.1818e-05 | norm: 2.9709 | dt: 6983.55ms | tok/sec: 2639.35
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] چو[BOM][SEP][CLS][BOM] با فای[BOM] از[SEP][CLS] فردوسی[CLS][BOM] به[SEP][CLS][CLS][CLS] فردوسی[CLS][CLS][BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM] به[BOM] و شد[SEP][CLS]کونامی[BOM][CLS][BOM][SEP][CLS] فردوسی[CLS][CLS][BOM] و[BOM] ز[BOM] و[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][BOM][BOM] احشام[BOM] از[BOM] بیسیم[SEP][CLS][CLS][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] به[BOM][SEP][CLS][BOM] ز[SEP]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM][BOM][BOM] به[BOM] پروتز[BOM][SEP][CLS][BOM] از و رونوشت[SEP][CLS][CLS][BOM][BOM][BOM] خدادادی[BOM][SEP][CLS][BOM]
# step    26 | loss: 7.164028 | lr 2.2657e-05 | norm: 2.9242 | dt: 7026.75ms | tok/sec: 2623.12
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] بر[BOM] به[BOM] ز[SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] به[SEP][CLS][CLS][CLS] فردوسی[CLS][CLS][BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM][BOM] به[BOM] به[BOM][BOM][SEP][CLS][BOM] که[SEP][CLS][CLS][CLS][CLS][BOM] که[SEP][CLS][BOM] و[BOM] به[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM]شمارند[BOM][BOM][SEP][CLS][BOM] احشام[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که[SEP][CLS][BOM] به[BOM] که[SEP][CLS][BOM] و
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM][BOM] به[SEP][CLS][CLS][BOM] به[BOM] به[SEP][CLS][CLS][BOM] چو[BOM] که[SEP][CLS][CLS][CLS][BOM] که[SEP][CLS]
# step    27 | loss: 7.113184 | lr 2.3497e-05 | norm: 2.8126 | dt: 7016.10ms | tok/sec: 2627.10
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] خور[BOM][SEP][CLS][BOM] به[SEP][CLS][BOM][SEP][CLS][CLS][BOM] و[BOM] و[SEP][CLS][CLS] فردوسی[CLS][CLS][BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] ز تیغ[SEP][CLS][BOM] ز[BOM] که و[BOM] که[SEP][CLS][BOM] ز[BOM] به[BOM] که
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] کرد[SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS][CLS] فردوسی[CLS][BOM] به[SEP][CLS][BOM] به[BOM] که[BOM] به[BOM] به[BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و[SEP][CLS][BOM] به[BOM] که[SEP][CLS][BOM] از[SEP][CLS][BOM] به وئیم[BOM] که[BOM] به
# step    28 | loss: 7.105085 | lr 2.4336e-05 | norm: 2.7239 | dt: 7015.66ms | tok/sec: 2627.27
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] خور[BOM] که[SEP][CLS][CLS][BOM][BOM] که[BOM] احشام[SEP][CLS][BOM] که[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM][SEP][CLS] فردوسی[CLS][BOM] ز بپرسید[BOM] که[SEP][CLS][BOM] که و[BOM] که[SEP][CLS][BOM] ز[BOM] به[BOM] که
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][CLS][BOM] چو[BOM] احشام[BOM] به[CLS] فردوسی[CLS][BOM] به[SEP][CLS][BOM] به[BOM] که[BOM] به[BOM] به[BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][SEP][CLS][BOM] که و و[BOM] به[BOM] که[SEP][CLS][BOM] از[BOM] که[SEP][CLS] فردوسی[CLS][BOM] که[BOM] به
# step    29 | loss: 7.065304 | lr 2.5175e-05 | norm: 2.6136 | dt: 6988.04ms | tok/sec: 2637.65
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] بر[BOM] که[BOM][BOM] به[BOM] همه[SEP][CLS][BOM] ز[SEP][CLS][CLS][CLS][BOM][SEP][CLS][CLS][BOM] ز[BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] ز[BOM] که پر[BOM] ز[SEP][CLS][BOM] ز[SEP][CLS] فردوسی[CLS][CLS][BOM] که[SEP][CLS][BOM] که[BOM] به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بارگذاری[BOM] به[BOM] که[BOM] که راه[SEP][CLS][CLS][CLS][BOM] به[SEP][CLS][BOM] به[BOM] به[BOM] به[BOM] به[SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز[BOM] به[SEP][CLS][CLS][BOM] به[BOM] که[BOM] به و خضوع[BOM] به[SEP][CLS][BOM] ز و[BOM] به[BOM] که
# step    30 | loss: 7.012164 | lr 2.6014e-05 | norm: 2.6480 | dt: 6961.28ms | tok/sec: 2647.79
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] بر[BOM] که[SEP][CLS][CLS][BOM] بپرسید[BOM] که[BOM] ز[SEP][CLS][BOM] به[BOM] ز و[BOM] که[BOM] ز[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] ز[SEP][CLS][CLS][BOM] ز بازیافت[SEP][CLS][BOM] ز[BOM] به و[SEP][CLS][BOM] به[SEP][CLS][BOM] که[BOM] به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] بیسیم از[BOM] که[SEP][CLS] فردوسی[CLS][BOM] که[BOM] به[BOM] که[SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] به[BOM] به و و[BOM] که[SEP][CLS][BOM] ز سودابه[SEP][CLS][CLS][BOM] ز و و[BOM] به[BOM] که
# step    31 | loss: 6.995083 | lr 2.6853e-05 | norm: 2.7953 | dt: 6938.96ms | tok/sec: 2656.31
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] به[BOM] از[SEP][CLS][CLS][BOM] به[SEP][CLS][BOM] به[SEP][CLS][BOM] ز و[SEP][CLS] فردوسی[CLS][BOM] به[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به[BOM] ز بارگذاری[SEP][CLS][BOM] ز[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که[SEP][CLS][BOM] به[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که[BOM] به[BOM] که[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] به و و[BOM] که[SEP][CLS][BOM] ز[SEP][CLS][CLS][BOM] ز و و[BOM] به[BOM] که
# step    32 | loss: 6.983351 | lr 2.7692e-05 | norm: 2.5443 | dt: 6937.88ms | tok/sec: 2656.72
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] همه[BOM] به[BOM][SEP][CLS][CLS][BOM] که[SEP][CLS][CLS][BOM][BOM] که[BOM] به[BOM] ز[BOM] که[BOM] ز[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به تیغ[BOM] ز[SEP][CLS][BOM] ز[SEP][CLS][CLS][BOM] به[BOM] به[SEP][CLS][BOM] که[BOM] به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بیامد[SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که[BOM] به[BOM] که[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] به و و گفتار[SEP][CLS] فردوسی[CLS][BOM] ز سودابه[BOM] که[BOM] که[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM]
# step    33 | loss: 6.944437 | lr 2.8531e-05 | norm: 2.6731 | dt: 6920.17ms | tok/sec: 2663.52
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] به[SEP][CLS][CLS][BOM] که[SEP][CLS][BOM] ز[SEP][CLS][BOM] به[BOM] ز و[BOM] که[BOM] ز[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به احشام[SEP][CLS][BOM][BOM] که[BOM] که و[BOM] که و[SEP][CLS] فردوسی[CLS][BOM] که و و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بر[SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که[SEP][CLS][BOM] که[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] به و والات[SEP][CLS][CLS][BOM] که و تیره[SEP][CLS] فردوسی[CLS][BOM] ز و[BOM] به[BOM] که
# step    34 | loss: 6.917822 | lr 2.9371e-05 | norm: 2.7054 | dt: 6922.20ms | tok/sec: 2662.74
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] که[SEP][CLS][CLS][BOM] بر[BOM] که[SEP][CLS][CLS] فردوسی[CLS][CLS][BOM] که[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به احشام[BOM] ز بارگذاری[SEP][CLS][BOM] ز[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] ز[SEP][CLS][BOM] به[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که[BOM] ز[SEP][CLS][BOM] که[BOM] به[BOM] به[BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] به و و خضوع[SEP][CLS][BOM] به[SEP][CLS][BOM] که[SEP][CLS][BOM] ز و بپرسید[BOM] به[BOM] که
# step    35 | loss: 6.881976 | lr 3.0210e-05 | norm: 2.4835 | dt: 6930.50ms | tok/sec: 2659.55
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] به[BOM] که[BOM] ز[SEP][CLS][BOM] که[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به[SEP][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] که‌[BOM] ز دین[SEP][CLS][BOM] ز[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] ز[BOM] به[BOM] به[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][BOM] به[BOM] که و[SEP][CLS][BOM] به با از از[SEP][CLS] فردوسی[CLS][BOM] که[SEP][CLS][CLS][BOM] که[SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و و خضوع[BOM] به[SEP][CLS][BOM] ز[SEP][CLS][CLS][BOM] ز وی[BOM] که[BOM] که
# step    36 | loss: 6.855229 | lr 3.1049e-05 | norm: 2.5001 | dt: 6957.11ms | tok/sec: 2649.38
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] به[BOM] که و کرد[SEP][CLS][CLS] فردوسی[CLS][BOM] ز[BOM] به و به[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] که[BOM] ز بارگذاری[SEP][CLS][BOM] ز از و[BOM] به[BOM] لشکر[SEP][CLS][CLS][CLS][BOM] که و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM] که و[BOM] همی[BOM] به ز از از[SEP][CLS][BOM] ز[SEP][CLS][CLS] فردوسی[CLS][BOM] که[SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و و[SEP][CLS][CLS][BOM] به و بهشهر[BOM] به[SEP][CLS] فردوسی[CLS][CLS][BOM] که[BOM] به
# step    37 | loss: 6.837105 | lr 3.1888e-05 | norm: 2.4643 | dt: 6951.96ms | tok/sec: 2651.34
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] به[BOM] که و خور[SEP][CLS][CLS] فردوسی[CLS][BOM] ز[BOM] به و به[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] که سودابه[BOM] زئیم[SEP][CLS][BOM] ز از و[BOM] به[BOM] تو[SEP][CLS][CLS][CLS][BOM] که[BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بیسیم[BOM] به راه[SEP][CLS][BOM][BOM] که[SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] به[SEP][CLS][BOM] به[SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و و سر[BOM] به[SEP][CLS][BOM] ز پذیرفت[SEP][CLS][CLS][BOM] ز وی[BOM] که[SEP][CLS]
# step    38 | loss: 6.785376 | lr 3.2727e-05 | norm: 2.3375 | dt: 6978.32ms | tok/sec: 2641.32
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که[SEP][CLS][CLS][BOM] به[BOM] که به تو[SEP][CLS][CLS] فردوسی[CLS][BOM] ز[BOM] به و به[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] که[BOM] ز تیره[SEP][CLS][BOM] ز از و و ز[BOM] لشکر[SEP][CLS][CLS][CLS][BOM] که[BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] سیکلت[SEP][CLS][BOM] به[SEP][CLS][CLS] فردوسی[CLS][BOM][BOM] به[BOM] به[SEP][CLS][BOM] به[BOM] که و[SEP][CLS][BOM] به
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و[BOM] بنشست[SEP][CLS][CLS][BOM] به و دین[BOM] به[BOM] به[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM]
# step    39 | loss: 6.749032 | lr 3.3566e-05 | norm: 2.3337 | dt: 6969.47ms | tok/sec: 2644.68
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که لشکر بارگذاری[BOM] به[SEP][CLS][CLS][BOM] همه[SEP][CLS] فردوسی[CLS][CLS] فردوسی[CLS][BOM] چو[BOM] که[SEP]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] ز[SEP][CLS] فردوسی[CLS][CLS][BOM] با[SEP][CLS][BOM] به[SEP][CLS][BOM] که بپرسید[SEP][CLS][CLS][BOM] به[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] به[BOM] به بپرسید[BOM] به با از از[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و به[SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] به به[BOM] ز[BOM] سخن[SEP][CLS][CLS] فردوسی[CLS][CLS][BOM] به که[BOM] به و وی[BOM] که با[SEP]
# step    40 | loss: 6.718791 | lr 3.4406e-05 | norm: 2.3224 | dt: 6986.07ms | tok/sec: 2638.39
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که چو آید[BOM] به و که تو[SEP][CLS][CLS] فردوسی[CLS][BOM] ز[BOM] به و[BOM] به[BOM] به
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] ز[SEP][CLS] فردوسی[CLS][CLS][BOM] به و ز و که و[SEP][CLS] فردوسی[CLS][BOM] به و به به[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] به[BOM] به بپرسید[BOM] به با از از[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و به[SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] ز سر[BOM] به[BOM] که[BOM] ز سر[SEP][CLS] فردوسی[CLS][CLS][CLS][CLS][BOM] که[SEP][CLS]
# step    41 | loss: 6.688243 | lr 3.5245e-05 | norm: 2.2646 | dt: 6951.04ms | tok/sec: 2651.69
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] که لشکر هامون پر[SEP][CLS] فردوسی[CLS][BOM] همه[BOM] که و[BOM] ز و به که از[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] ز[SEP][CLS] فردوسی[CLS][CLS][BOM] به و[SEP][CLS][BOM] که[BOM] به[SEP][CLS] فردوسی[CLS][BOM] به[SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] به ز[SEP][CLS] فردوسی[CLS][BOM] از که[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که و به[BOM] به که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] ز سخن[BOM] به و به از[BOM] گریز[BOM] به و از[SEP][CLS][BOM] به و چو[SEP]
# step    42 | loss: 6.647309 | lr 3.6084e-05 | norm: 2.3194 | dt: 6966.23ms | tok/sec: 2645.91
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به و به که لشکر سخن[BOM] به و و بدرند بر[SEP][CLS][CLS][BOM] ز و به که از[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] ز پیش[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] به و که ز[SEP][CLS] فردوسی[CLS][BOM] به به به[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که[BOM] به و چو[SEP][CLS][CLS][BOM] همی از از[SEP][CLS][CLS] فردوسی[CLS][BOM] به به و به[BOM] به از
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که که بهرند[SEP][CLS][CLS] فردوسی[CLS][CLS][BOM] به از و که به و پر[BOM] ز[BOM] به
# step    43 | loss: 6.634526 | lr 3.6923e-05 | norm: 2.8803 | dt: 6945.03ms | tok/sec: 2653.98
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] ز شد[BOM] به بر[SEP][CLS][CLS][BOM] همه[SEP][CLS] فردوسی[CLS][CLS] فردوسی[CLS][BOM] چو[BOM] که[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[BOM] که و کهئیم[SEP][CLS][CLS][BOM] ز کهرند[SEP][CLS][BOM] به و خور[BOM] که[CLS] فردوسی[CLS] فردوسی[CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که ز و شد[BOM] به[CLS] فردوسی[CLS][BOM] به[SEP][CLS][BOM] به[SEP][CLS] فردوسی[CLS][BOM] به[BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] به که[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] به[BOM] که ز و باشی[BOM] به[SEP][CLS][BOM] که شهنشاه[BOM] ز و که
# step    44 | loss: 6.607145 | lr 3.7762e-05 | norm: 4.6061 | dt: 7019.02ms | tok/sec: 2626.01
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] ز لشکر آتش شهنشاه[SEP][CLS] فردوسی[CLS][BOM] همه[SEP][CLS][BOM] که به بر و[SEP][CLS][CLS] فردوسی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به به به[SEP][CLS] فردوسی[CLS][BOM] که که[SEP][CLS][BOM] ز[BOM] به که خور[BOM] که[SEP][CLS][CLS] فردوسی[CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به را[BOM] که و بد[BOM] ز[BOM] از و به به و که[SEP][CLS][CLS][CLS][BOM] به[SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] به و که به تیغ[SEP][CLS][CLS] فردوسی[CLS][CLS][BOM] به ز و ز[BOM] ز پر[SEP][CLS] فردوسی[CLS]
# step    45 | loss: 6.552420 | lr 3.8601e-05 | norm: 2.4037 | dt: 6944.50ms | tok/sec: 2654.19
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به بهش از لشکر تیغ[BOM] به ز[CLS][CLS][BOM] همه[SEP][CLS][BOM] که به بر[SEP][CLS][CLS][BOM] که[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] که[BOM] به گفت هر و[SEP][CLS][CLS][BOM] ز[BOM] که‌[BOM] به ز به که از[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که شهنشاه[BOM] به[CLS][BOM] خور[SEP][CLS] فردوسی[CLS][BOM] ز که که و به به به و ز و به[BOM] ز
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] که ز[SEP][CLS] فردوسی[CLS][BOM] که بر[BOM] نه ز از از پر[SEP][CLS][BOM] ز به با که
# step    46 | loss: 6.514945 | lr 3.9441e-05 | norm: 2.4396 | dt: 6953.92ms | tok/sec: 2650.59
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که[BOM] بهش بود[BOM] که سان و شد دین به[SEP][CLS][CLS][BOM] ز بر[SEP][CLS][BOM] که و[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به به[BOM] که[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM][BOM] به و[SEP][CLS][BOM] ز به که به[SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به شد[BOM] ز و بد[SEP][CLS][BOM] از و به[CLS] فردوسی[CLS][BOM] که و که و به[SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] به و که به هست[BOM] به ز و بر[CLS][BOM] به از و سوی[SEP][CLS][BOM] که و با[SEP]
# step    47 | loss: 6.514734 | lr 4.0280e-05 | norm: 5.7353 | dt: 6956.54ms | tok/sec: 2649.59
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به به به[SEP][CLS] فردوسی[CLS][BOM] به که خور دین که به ز تیغ با به بر[SEP][CLS][CLS][BOM] به از
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به گفتار به ز کرد[SEP][CLS] فردوسی[CLS][BOM] به ز[BOM] به هر[BOM] ز[SEP][CLS][CLS] فردوسی[CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز تیغ[BOM] به چو به همه[SEP][CLS][CLS] فردوسی[CLS][BOM] که که ز به به به که پر به به[BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که و ز ز[SEP][CLS][BOM] که[CLS][BOM] که از درفش[BOM] که که[SEP][CLS][BOM] به به که با و
# step    48 | loss: 6.457429 | lr 4.1119e-05 | norm: 2.2131 | dt: 6979.36ms | tok/sec: 2640.93
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که کهش ز لشکر چو بپرسید[BOM] که که را تیره بر[CLS] فردوسی[CLS] فردوسی[CLS] فردوسی[CLS][BOM] ز[BOM] به از
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ز به و خردمند[BOM] ز‌‌ و[SEP][CLS][CLS][CLS][CLS][BOM] به هر به به[BOM] که ز که که
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] زی[BOM] به چو به تو[BOM] که چو از از[CLS][CLS][BOM] ز به به به که راه[SEP][CLS][CLS] فردوسی
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که و ز که به ریخت[SEP][CLS][CLS][BOM] که و او[BOM] که که‌[SEP][CLS][BOM] که از[CLS][CLS]
# step    49 | loss: 6.412297 | lr 4.1958e-05 | norm: 4.6026 | dt: 6937.07ms | tok/sec: 2657.03
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM][BOM] که گفت پر به ز که چو‌ بر[CLS][BOM] به بر به[CLS][BOM] ز که[SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] ز[BOM] به[BOM] ز کرد[SEP][CLS][BOM] ز که از و بر[SEP][CLS][CLS][BOM] ز به از[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که همه[BOM] ز و خور[BOM] که با از که[CLS] فردوسی[CLS][BOM] که و به وی[SEP][CLS][BOM] که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] که که از و دین[SEP][CLS][CLS][BOM] که از ریخت[BOM] که از خور[SEP][CLS][BOM] که از[CLS][BOM]
# step    50 | loss: 6.386812 | lr 4.2797e-05 | norm: 6.7197 | dt: 6928.75ms | tok/sec: 2660.22
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] به[BOM] به لشکر آید راه[BOM] به ز بد تیره که از[CLS] فردوسی[CLS][BOM] به به از که و و[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که و به ز سان[BOM] ز باشی[SEP][CLS] فردوسی[CLS][BOM] به که بر به راه[SEP][CLS] فردوسی[CLS][BOM] به و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که همه[BOM] ز به تو و به با از[SEP][CLS][CLS][BOM] ز و به به و راه[SEP][CLS] فردوسی[CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به به که از به تیغ[BOM] که[CLS][BOM] که به تیغ[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] که به با که
# step    51 | loss: 7.874789 | lr 4.3636e-05 | norm: 7.3263 | dt: 6922.61ms | tok/sec: 2662.58
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به که[SEP][CLS] فردوسی[CLS][BOM] که درفش و هر گفت که به از سان بر به[SEP][CLS][BOM] ز[CLS] فردوسی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] که ز نماند و که دین راه[SEP][CLS][CLS][BOM] به و[CLS] فردوسی[CLS][BOM] ز از[CLS][BOM] به و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز او بد به بر[CLS][BOM] به به با از ز و با و از[CLS][CLS][BOM] به پر به به[SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] فردوسی[CLS][BOM] که و ز که به جنگ[BOM] که[CLS][BOM] که و مهان[SEP][CLS] فردوسی[CLS][BOM] ز همه و و با که
# step    52 | loss: 7.693494 | lr 4.4476e-05 | norm: 7.2829 | dt: 6931.68ms | tok/sec: 2659.09
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] ز و تو تیغ کرد[CLS][CLS][BOM]ش راه بر[CLS][BOM] که[SEP][CLS][CLS][BOM] ز از[CLS][BOM] به
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به و به از همه و وی تو[CLS][BOM] ز بر[CLS] فردوسی[CLS][BOM] سوی به و که[CLS][BOM] که از
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز دین شد‌[CLS][BOM] خور[BOM] که چو که[CLS][BOM] به به[CLS][BOM] که[CLS][BOM] به[CLS][BOM] به ز
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به به به[CLS][BOM] ز کرد[BOM] به[CLS][BOM] به و این ز که[CLS][CLS][BOM] ز بد به به بر[CLS]
# step    53 | loss: 7.480626 | lr 4.5315e-05 | norm: 7.3890 | dt: 6925.65ms | tok/sec: 2661.41
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] با[CLS] فردوسی[CLS][BOM] بر هامون گفت[BOM] که[CLS][BOM] هست به[CLS][BOM] که[CLS][BOM] که[CLS][BOM] از[CLS][BOM] به
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به و[CLS][BOM] خردمند[BOM] ز تاج سوی[CLS][BOM] چنین[BOM] که[CLS][BOM] که[CLS][CLS][BOM][CLS][BOM] به از و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM][SEP][CLS][BOM] همی[CLS][BOM] که تو[CLS][BOM] همه[BOM][CLS][BOM] به[CLS][BOM] به[CLS][BOM] که بد[CLS][BOM] به[CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] به[CLS][BOM] ز از خرد[CLS][BOM] که[CLS][BOM] ز تاج[SEP][CLS][BOM] شد[CLS][BOM] آید[CLS][CLS][BOM] به
# step    54 | loss: 7.361676 | lr 4.6154e-05 | norm: 6.2716 | dt: 6939.41ms | tok/sec: 2656.13
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] با[CLS][CLS][BOM] از[CLS][BOM] تیره بر[CLS][BOM] شد ای به[CLS][BOM] سان از[SEP][CLS][BOM] ز[CLS][BOM] به[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][BOM] به[CLS][BOM] به به تیغ[BOM] ز ای[CLS][CLS][BOM] بران از[CLS][BOM] ز و تو[BOM][BOM] از[CLS][BOM] که[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] بیامد از[CLS][BOM] به بر[CLS][BOM] که[CLS][BOM] از[BOM] به[CLS][BOM] که[CLS][BOM] به و‌[CLS][BOM][SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] به[CLS][BOM] ز و به و شهنشاه[CLS][BOM] از[CLS][BOM][BOM][SEP][CLS][BOM] که[CLS][BOM][BOM] بپرسید[CLS][CLS][BOM] و
# step    55 | loss: 7.234925 | lr 4.6993e-05 | norm: 5.2093 | dt: 6934.12ms | tok/sec: 2658.16
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][BOM] با[CLS][SEP][CLS][BOM]ش بپرسید بپرسید[SEP][CLS][CLS][BOM] بخواند بر[CLS][BOM] ای از و و و و[BOM][SEP][CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] به[CLS][BOM] ای[SEP][CLS][BOM] بد و به خور از[SEP][CLS][CLS][CLS][BOM] به[BOM] و و[BOM] به[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][BOM] پر[BOM] پر تو[SEP][CLS][CLS][BOM] ز[CLS] به از از[CLS][BOM][SEP][CLS][BOM] که[CLS][BOM] بپرسید[SEP][CLS][BOM] از
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از[BOM] و و[SEP][CLS][BOM][CLS][BOM] از شد که و هامون[BOM][BOM] و[CLS][CLS][SEP][CLS][BOM][BOM] با[CLS]
# step    56 | loss: 7.100946 | lr 4.7832e-05 | norm: 4.5110 | dt: 6905.59ms | tok/sec: 2669.14
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM] چو بهش آید راه[SEP][CLS][CLS][BOM] ای به و[CLS][BOM][BOM] و بر[SEP][CLS][CLS][BOM][BOM] ز
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] و و[BOM] دین[SEP][CLS][CLS][CLS][BOM][SEP][CLS][BOM][BOM][BOM] ز و‌ از[CLS][CLS][BOM][SEP][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و مولوی[CLS][BOM] ز و هر و[SEP][CLS][CLS][BOM][BOM] از[CLS][BOM] که[CLS][CLS][SEP][CLS][BOM][BOM] از که
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از[BOM][BOM] به از و تیره[SEP][CLS][CLS][BOM] ز[SEP][CLS][CLS][BOM] به تو[BOM][BOM] خور[SEP][CLS][CLS][CLS]
# step    57 | loss: 6.984319 | lr 4.8671e-05 | norm: 4.2457 | dt: 6921.93ms | tok/sec: 2662.84
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM] چو[CLS][BOM] هست او ز سر[BOM] شد تیغ به و که پر ز[CLS][CLS][BOM] به[BOM] که از[SEP]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] از از[BOM] پر از[SEP][CLS][CLS][BOM] ز بخواند[CLS][BOM] و با از او از از[BOM] که[CLS][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و تیغ شد[BOM] ز و کرد[SEP][CLS][CLS] و که و را[SEP][CLS][CLS][CLS][BOM] که راه[BOM][BOM] به به
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به[BOM] به از[SEP][CLS][CLS][BOM] که پر شد ز[SEP][CLS][CLS][BOM][BOM]‌ از[SEP][CLS][CLS][CLS][BOM] و
# step    58 | loss: 6.869305 | lr 4.9510e-05 | norm: 4.1339 | dt: 6921.73ms | tok/sec: 2662.92
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] کهش بهش هست لشکر[BOM][SEP][CLS][CLS][BOM] ز و که هامون که[SEP][CLS][CLS] مولوی[CLS][BOM] که گفت
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] از از که تیغ[BOM][BOM] گفت بد از به سر که[SEP][CLS][CLS][BOM] کرد از[BOM] به سوی از[BOM] از
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و[BOM] کرد[BOM][SEP][CLS] مولوی[CLS][BOM] بر به به[BOM] که و از از از از و راه[SEP][CLS][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][BOM] که که از[SEP][CLS][CLS][BOM] دید[BOM] که تیغ و ز از دین[BOM] به و مولوی[CLS] مولوی[CLS][BOM] که را[BOM]
# step    59 | loss: 6.782354 | lr 5.0350e-05 | norm: 3.9791 | dt: 6918.79ms | tok/sec: 2664.05
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM] را[SEP][CLS] مولوی[CLS][BOM] ز که بد در به[BOM] به دین که که به[BOM] به[SEP][CLS] مولوی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] از از که همه[BOM][BOM] هامون بد از به گفت که[SEP][CLS][CLS] مولوی[CLS] مولوی[CLS][BOM] که که از و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و[BOM] تو[BOM][SEP][CLS][CLS] مولوی[CLS][BOM] به به[BOM] که[BOM] از از از از و لشکر که از که با
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] مولوی[CLS][BOM][BOM] و و از از دین[BOM] ز شهنشاهی[BOM][BOM] تیغ بای[BOM] شد[SEP][CLS][CLS][CLS][CLS][BOM] و
# step    60 | loss: 6.740641 | lr 5.1189e-05 | norm: 2.8846 | dt: 6940.11ms | tok/sec: 2655.86
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ازش به هر تیغ در[SEP][CLS] مولوی[CLS][BOM] به[BOM][SEP][CLS][CLS][CLS] مولوی[CLS][BOM] و[BOM] که تیره
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که و[BOM][BOM] نگه[SEP][CLS][CLS] مولوی[CLS][BOM] بود که و از به و شد از از که این[SEP][CLS] مولوی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و تیغ شد[BOM] به[SEP][CLS][CLS] مولوی[CLS][BOM] به[BOM] و و از از از[SEP][CLS] مولوی[CLS][BOM][SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] مولوی[CLS][BOM][BOM] و از که[BOM] دید[SEP][CLS][CLS][BOM][SEP][CLS][BOM] با تو[BOM] او از[SEP][CLS][CLS][BOM] را از
# step    61 | loss: 6.704750 | lr 5.2028e-05 | norm: 3.7399 | dt: 6926.85ms | tok/sec: 2660.95
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که وش به هر آتش سوی[SEP][CLS] مولوی[CLS][BOM] به[BOM] و آتش که و بر[SEP][CLS] مولوی[CLS] مولوی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS] مولوی[CLS][BOM] و[BOM][BOM] من[SEP][CLS][CLS][BOM] از به آن که[SEP][CLS] مولوی[CLS][BOM][SEP][CLS] مولوی[CLS][BOM] و و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و تیغ شد[SEP][CLS] مولوی[CLS][BOM] که بر که[BOM] که ز و از[SEP][CLS][CLS] مولوی[CLS][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS] مولوی[CLS][BOM][BOM] و از[SEP][CLS] مولوی[CLS][BOM] تا‌ ز[SEP][CLS] مولوی[CLS][BOM]ی و از بد و[SEP][CLS] مولوی
# step    62 | loss: 6.674868 | lr 5.2867e-05 | norm: 3.1961 | dt: 6931.32ms | tok/sec: 2659.23
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ازش به هر تیغ[SEP][CLS][CLS][BOM] در تیره به[BOM] از آتش که و به[SEP][CLS][CLS][BOM] که[SEP]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که و[BOM] و هست[SEP][CLS][CLS][BOM] از به بپرسید که از و به[BOM] این از[SEP][CLS][CLS][BOM][BOM] که
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و تیره شد[SEP][CLS][BOM] در[BOM] که به که[BOM] که با از[SEP][CLS][CLS][CLS] مولوی[CLS][BOM][SEP][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][SEP][CLS][BOM][BOM] و[BOM] دید[SEP][CLS][CLS][BOM] به از باشی بر تو[BOM] چون[SEP][CLS][CLS] مولوی[CLS][BOM][BOM]
# step    63 | loss: 6.618374 | lr 5.3706e-05 | norm: 3.3913 | dt: 6945.53ms | tok/sec: 2653.79
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM][BOM]ش به را گفت چون[SEP][CLS][CLS][BOM] بد به[BOM][BOM] آن[BOM][SEP][CLS][CLS][CLS][BOM] که و تیغ
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] از از[BOM] ما[SEP][CLS][CLS][CLS][BOM] به تیغ که و[SEP][CLS] مولوی[CLS][CLS][BOM][SEP][CLS][BOM] از و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و هامون در[BOM] به[BOM] را[BOM][SEP][CLS][CLS][CLS][BOM] بر[SEP][CLS][CLS][CLS][BOM] که آن[BOM][BOM][SEP][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز[BOM] و از و و بود[SEP][CLS][CLS][BOM] به و بپرسید[BOM]‌[BOM] کرد[SEP][CLS][CLS][CLS] مولوی[CLS][BOM]
# step    64 | loss: 6.570509 | lr 5.4545e-05 | norm: 6.0223 | dt: 6936.51ms | tok/sec: 2657.24
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] که در بهش تا راه[SEP][CLS][CLS][BOM] پیش را[BOM][SEP][CLS][CLS] مولوی[CLS][BOM] ز که از و[BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM][BOM] از از[SEP][CLS][CLS][BOM] تیره چون و به سر که و[SEP][CLS] مولوی[CLS][CLS][BOM][SEP][CLS][BOM] و و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] و هامون‌ تا ز[BOM] این[SEP][CLS][CLS][BOM][SEP][CLS][BOM] از و[BOM] که از[BOM] لشکر که از که تو
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز[BOM] و از این و یک[SEP][CLS][CLS][BOM] به[SEP][CLS][CLS][BOM] که چون[BOM][BOM] سوی از[SEP][CLS][CLS]
# step    65 | loss: 6.529031 | lr 5.5385e-05 | norm: 2.3824 | dt: 6994.00ms | tok/sec: 2635.40
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که[BOM] در به تو ما آن[SEP][CLS][CLS][BOM] هامون به[BOM][BOM] ما که که[BOM] که ز که از از بد
# ...
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از ز را و تو و آید[SEP][CLS][CLS][BOM] که به در به پیش[BOM] چنین که  پر به و با[SEP]
# step   105 | loss: 5.079257 | lr 8.8951e-05 | norm: 12.9036 | dt: 6925.41ms | tok/sec: 2661.50
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز به[BOM] و تو راه[SEP][CLS][CLS][BOM] شد من بر به از سوی به بر[BOM] که را هر[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از بد از همه[SEP][CLS][CLS][BOM] ز را‌ بر به[BOM][SEP][CLS][CLS][BOM] به بر پیش[SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به این او ما از[SEP][CLS][CLS][BOM] تو به که به که او[BOM] که تا به به شاه[SEP][CLS][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو ز را[BOM] که و گشت[SEP][CLS][CLS][BOM] که از آن را گفت و پیش[SEP][CLS][CLS][BOM] زی[SEP]
# step   106 | loss: 5.047577 | lr 8.9790e-05 | norm: 7.9679 | dt: 6926.46ms | tok/sec: 2661.10
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ز او بر او من[BOM] به گشت[SEP][CLS][CLS][BOM] که[BOM] تا[SEP][CLS][CLS][BOM] به چو ز بهم
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از بد[BOM] بود[SEP][CLS][CLS][BOM] ز و این از بر[BOM] هم به سر بر آمد بر[SEP][CLS][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو من او لشکر به[SEP][CLS][CLS][BOM] همی از که ازی[SEP][CLS][CLS][BOM] که ز پر ز[SEP][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو ز را[BOM] که بر تای[SEP][CLS][CLS][BOM] به در بر تو[SEP][CLS][CLS][CLS][BOM] که از با ز
# step   107 | loss: 5.036511 | lr 9.0629e-05 | norm: 6.1272 | dt: 6928.93ms | tok/sec: 2660.15
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از[SEP][CLS][CLS][BOM] تا با پس که تو یک بر[SEP][CLS][CLS][BOM] به ز بری[BOM] که از ما
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به بود[BOM] بد به به آن پیش و از لشکر بر[BOM] ز که[BOM] یکی بران[SEP][CLS][CLS][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو من او[BOM] ز ز سر سوی[SEP][CLS][CLS] فردوسی[CLS][BOM] ز[BOM] که سخن[BOM] ز شاه[SEP][CLS][CLS] فردوسی
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو[BOM] چو به هر او در به از یک[SEP][CLS][CLS][BOM] همه او[SEP][CLS][CLS][CLS][BOM] که از و را
# step   108 | loss: 5.012234 | lr 9.1469e-05 | norm: 8.2389 | dt: 6924.17ms | tok/sec: 2661.98
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که[BOM] به و شد راه[SEP][CLS][CLS][BOM] سر من بر سر بر آن با بر به[SEP][CLS][CLS] فردوسی[CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به  و همه[SEP][CLS][CLS][BOM] ز به آن از بر وی[SEP][CLS][CLS] فردوسی[CLS][BOM] که بر[SEP]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو سوی شد تا و[SEP][CLS][CLS][BOM][BOM] از که از[SEP][CLS][CLS][BOM] که ازیم هر[SEP][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو ز را[BOM] ز که کار[SEP][CLS][CLS][BOM] که به آنی[SEP][CLS][CLS][BOM] ز بود[BOM] به با از
# step   109 | loss: 4.960257 | lr 9.2308e-05 | norm: 6.8298 | dt: 6938.46ms | tok/sec: 2656.50
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ز توی که آن پر[BOM] چه از پیش راهی[SEP][CLS][CLS] فردوسی[CLS][BOM] که که بد به بر ما
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به بد ازای[SEP][CLS][CLS][BOM] ز را این بر از[BOM][CLS] فردوسی[CLS][BOM] ز و هر بد[SEP][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو لشکرش لشکری[SEP][CLS] فردوسی[CLS][BOM] چو بر[BOM] که[BOM] ز بر گشت[SEP][CLS] فردوسی[CLS][BOM] که و
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو زی و سر وای[SEP][CLS][CLS][BOM] که و‌ به هر تا سر[SEP][CLS][CLS][BOM] به با به
# step   110 | loss: 4.951145 | lr 9.3147e-05 | norm: 2.2974 | dt: 6967.41ms | tok/sec: 2645.46
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که و[SEP][CLS][CLS][BOM] او بر بی و سر منی[SEP][CLS][CLS][BOM] زی[SEP][CLS] فردوسی[CLS] فردوسی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به بود را این[SEP][CLS] فردوسی[CLS] فردوسی[CLS][BOM] از و از به[SEP][CLS][BOM] که[SEP][CLS] فردوسی[CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو کرد تو تا ز[SEP][CLS][CLS][BOM] همی که[SEP][CLS][BOM] ز گفت[BOM] که را و‌[SEP][CLS][CLS] فردوسی
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از را[BOM] ز[SEP][CLS][CLS][BOM] پیش گفت که از همه به هرند[SEP][CLS][CLS][CLS][BOM] به[SEP][CLS]
# step   111 | loss: 4.921094 | lr 9.3986e-05 | norm: 2.5111 | dt: 6948.74ms | tok/sec: 2652.57
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از تو از او بی سر[SEP][CLS][CLS][BOM] سخن را[BOM] از دری و را[SEP][CLS][CLS] فردوسی[CLS][BOM]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که[BOM] به از همه و بر بی ز و از[CLS] فردوسی[CLS][BOM] چو و گفت از تا[BOM] که[SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو کرد تو تا ز و تو[SEP][CLS][CLS][BOM] از و[SEP][CLS] فردوسی[CLS][BOM] که[BOM] این سر و ز سر
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از و که[SEP][CLS] فردوسی[CLS][BOM] که راه[BOM] همه به این را او[SEP][CLS][CLS][CLS][BOM] که[BOM] همی به
# step   112 | loss: 4.921268 | lr 9.4825e-05 | norm: 2.1347 | dt: 6949.09ms | tok/sec: 2652.43
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ازی بر او یک پر گفت و[SEP][CLS][CLS][BOM] که به این که[BOM] همی و ز شد[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به شاه وم[SEP][CLS][CLS][BOM] به ز ما[SEP][CLS][CLS][BOM] به سر از تا از پیش[SEP][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو لشکرش‌ آن و تو[SEP][CLS][CLS][BOM] از و را و[BOM] که و و[SEP][CLS][CLS] فردوسی[CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از و را[SEP][CLS] فردوسی[CLS][BOM] چو پس اوی[SEP][CLS][CLS][BOM] به  و من پیش و ازان[SEP]
# step   113 | loss: 4.871908 | lr 9.5664e-05 | norm: 1.7989 | dt: 6975.21ms | tok/sec: 2642.50
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از سر[BOM] یکی آمد منی[SEP][CLS][CLS][BOM] و و زمی و[SEP][CLS][CLS][BOM] که از در
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که به شاه و کار[BOM] ز دو  تو از در را[BOM] ز من و هر[SEP][CLS][CLS][CLS][BOM] به به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو تا شد این راه[SEP][CLS][CLS][BOM] همی[BOM] از و سر تو[SEP][CLS][CLS][BOM] به راه[SEP][CLS][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از و از بر سر[BOM] کسی و و آمد او[SEP][CLS][CLS][BOM] یکیای بد و گفت هر[CLS] فردوسی[CLS][BOM]
# step   114 | loss: 4.899771 | lr 9.6503e-05 | norm: 6.3956 | dt: 6952.16ms | tok/sec: 2651.26
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز ز تو ازی من پیش[SEP][CLS][CLS][BOM]ش[BOM] به از‌ او[SEP][CLS][CLS][BOM] چو پس ز همه
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز به شاه[BOM]ش و از در هر[SEP][CLS][CLS][BOM] که به من وش به[CLS][BOM] شد[BOM] که از
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو تا شد اینان[BOM] گفت لشکر و تو را[SEP][CLS][CLS] فردوسی[CLS][BOM] که و[BOM] او بود[SEP][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از تو[BOM] که از خاک و[SEP][CLS][CLS][BOM] ز جای که تو و من[SEP][CLS][CLS][BOM] به[BOM] چو
# step   115 | loss: 4.863197 | lr 9.7343e-05 | norm: 6.5996 | dt: 6969.52ms | tok/sec: 2644.66
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز به او از هر اندر سرش[BOM] چوش تا[BOM] به از کردی و با[SEP][CLS][CLS][CLS] فردوسی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از همه به دو[BOM] ز جای راه[BOM] و کرد از و از بود[BOM] سر بر کار[SEP][CLS][CLS][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو پر همی سوی اندر و هر بد[SEP][CLS][CLS] فردوسی[CLS][BOM] به[BOM] که همی به بر کرد[BOM] که[BOM] و
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از با بر هر[BOM] بران با را دل ز به[SEP][CLS][CLS][CLS][BOM] نه در به راه[BOM] که او را
# step   116 | loss: 4.943662 | lr 9.8182e-05 | norm: 18.9662 | dt: 6954.27ms | tok/sec: 2650.46
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از تو ازیند[SEP][CLS][CLS] فردوسی[CLS][BOM] چو[BOM] از بود را که او[BOM] ز لشکر آن و‌
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز بهی از جای[SEP][CLS][CLS][BOM] ز[BOM] تا و بر از آن[SEP][CLS][CLS][CLS][BOM] نه که بر به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو پر همی سوی اندر و هر کرد[SEP][CLS][CLS] فردوسی[CLS][BOM][BOM] ز از جنگ[BOM] که آمدش و ز شد
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از با بر سر[SEP][CLS][CLS][BOM] من تو را و ما[SEP][CLS][CLS] فردوسی[CLS][BOM] تا به به گفت[BOM]
# step   117 | loss: 4.982985 | lr 9.9021e-05 | norm: 19.6540 | dt: 6988.69ms | tok/sec: 2637.40
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از تو ازی آمد کرد[SEP][CLS][CLS][BOM]ش[BOM] ز و همه ز از[BOM] به را شاه[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز بر پیش[SEP][CLS][CLS][BOM] دو شاه و با کرد بر و[BOM] همی[BOM] گفت ازم[SEP][CLS][CLS][CLS][BOM]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو دو  در پر از  راه[SEP][CLS][CLS][BOM] به که‌ بر و سوی[SEP][CLS][CLS] فردوسی[CLS][BOM] از
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از با بر که[SEP][CLS][CLS][BOM] هم شد که و جای[SEP][CLS][CLS][BOM] ز آن همی که از او[BOM]
# step   118 | loss: 4.826404 | lr 9.9860e-05 | norm: 5.1594 | dt: 6947.77ms | tok/sec: 2652.94
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز ز  که که پر کرد[SEP][CLS][CLS][BOM] او را به  اینش و با[SEP][CLS][CLS][BOM] که این
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از پیش[SEP][CLS] فردوسی[CLS][BOM] نه[BOM] همه این بر از و گفت[BOM] سر به دل به[BOM] چو از و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو لشکر سر در راه[SEP][CLS] فردوسی[CLS][BOM] چو که ازان و شاه[BOM] به بر بران[SEP][CLS][CLS][BOM]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از با از  ز دلش[SEP][CLS] فردوسی[CLS][BOM] را را او دل  در[SEP][CLS] فردوسی[CLS][BOM] چو
# step   119 | loss: 4.836412 | lr 1.0070e-04 | norm: 3.7767 | dt: 6973.48ms | tok/sec: 2643.16
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از او به هر تا اندر کهند[SEP][CLS][CLS][BOM] به و اینش و ز و از که[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز زی که جای[SEP][CLS] فردوسی[CLS][BOM][BOM] هم بر از به هر از که[SEP][CLS][CLS][BOM] چو ز و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو این سر همه اندر و  آمد وش را[SEP][CLS][CLS] فردوسی[CLS][BOM] به[BOM] که تای[SEP][CLS] فردوسی
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از از با از ی سوی[SEP][CLS] فردوسی[CLS][BOM] ز داد[SEP][CLS] فردوسی[CLS][BOM] ز بد به بر با از
# step   120 | loss: 4.811228 | lr 1.0154e-04 | norm: 2.2923 | dt: 6964.64ms | tok/sec: 2646.51
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز از گفت را شدند[SEP][CLS][CLS] فردوسی[CLS][BOM] از[BOM] ازو را[BOM] همه و باان[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP] گفت سر این[BOM] ز بود از یک و بر آن پر اوی سر را[SEP] و من[BOM] گفت بر ما[SEP][CLS][CLS][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو دو سر همی پیش[SEP][CLS] فردوسی[CLS][BOM] چو ز[BOM] چنینم از بر کس و از ز تو[SEP][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از بر با بر بود[BOM] تا[BOM] به کار بودش[BOM] همان که ز دو [BOM] ز پیش[SEP] وی[SEP]
# step   121 | loss: 4.788023 | lr 1.0238e-04 | norm: 1.9701 | dt: 6965.08ms | tok/sec: 2646.34
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز[BOM] بر ز[BOM] سویان به این را اندر راهی[SEP][CLS][CLS][BOM] زی[BOM] همی کرد[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز و شد را کار[SEP][CLS][CLS][BOM] به به کرد بر بر[BOM] و بر من[SEP][CLS][CLS] فردوسی[CLS][BOM] به
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو این  دو اندر[BOM] یکی پر از با بر را[SEP][CLS][CLS] فردوسی[CLS][BOM] به و آمد[BOM] که از من
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو از به وان[SEP][CLS][CLS][BOM] چه شد را به جای[SEP][CLS] فردوسی[CLS][BOM] ز راه[BOM] به با از
# step   122 | loss: 4.776910 | lr 1.0322e-04 | norm: 1.3510 | dt: 6965.80ms | tok/sec: 2646.07
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز و سری بام بد از ز و بود[SEP][CLS][CLS][BOM] بروش[BOM] چنین گفت به تو[SEP][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] ز ازو از دو[BOM] ز لشکر من وی[SEP][CLS][CLS][BOM] همه بر سر را[SEP][CLS][CLS][BOM] چو از
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو داد شاهم آمد و به آمد[SEP][CLS][BOM] همی و شاه[SEP][CLS][CLS][BOM] که و بد بود[BOM] که آمد
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو از به را تو وو[SEP][CLS][CLS][BOM] همه  پس را کرد[BOM] سخن یک منم[SEP][CLS][CLS][BOM]
# step   123 | loss: 4.800488 | lr 1.0406e-04 | norm: 4.6538 | dt: 6947.08ms | tok/sec: 2653.20
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از سر به با پر من[SEP][CLS] فردوسی[CLS][BOM] همی[BOM] همی همی که وان[SEP][CLS][CLS][BOM] ز اندر
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که گفت بد از خاک[SEP][CLS][BOM] چه شاه[SEP][CLS][CLS][BOM] چوی و هر[SEP][CLS][CLS][BOM] چو ز را
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به بودش در تا و پیش[SEP][CLS][BOM] همیی[SEP][CLS][CLS][BOM] که رنج و گفت سر گفت و اندر آمد
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به گفت را و هر را بی با[SEP][CLS] فردوسی[CLS][BOM] اگر گفت تا کار بدست و راه[SEP][CLS][CLS][BOM]
# step   124 | loss: 4.810733 | lr 1.0490e-04 | norm: 5.7826 | dt: 6960.84ms | tok/sec: 2647.96
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که گفت شاه[BOM] بدو لشکر تا[SEP][CLS][CLS][BOM] شد که بد بران با را[BOM] کهی[SEP][CLS][CLS][CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که از آمد و بود[SEP][CLS][CLS][BOM] ز وش از بر[BOM][SEP][CLS][CLS][BOM] که تو سر بدی و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به در چو بی بود[SEP][CLS][CLS][BOM] یکی و با را که دست[BOM] کهه[SEP][CLS][CLS][CLS][BOM] که شد
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] به گفت را به با را سخن[SEP][CLS][CLS][BOM] همه بد جهان[SEP][CLS][CLS][BOM] به بد آمد ز بر سر[SEP]
# step   125 | loss: 4.749907 | lr 1.0573e-04 | norm: 2.1933 | dt: 6953.23ms | tok/sec: 2650.85
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که ازی ازو بی پر[BOM] سوی[SEP][CLS][CLS][CLS][BOM] همی جهان که و گفت[BOM][SEP][CLS][CLS] فردوسی[CLS]
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که گفت  را گفت[BOM] ز به بود[SEP][CLS][CLS] فردوسی[CLS][BOM] همی وش که آمد از تو[SEP][CLS][CLS]
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو دو او روی پر ازش[SEP][CLS][CLS][BOM] همی[BOM] یکی این را[SEP][CLS][CLS][CLS] فردوسی[CLS][BOM] که را
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو گفت که و به را سخن[SEP][CLS][CLS][BOM] همه را سخن[BOM] تو ما پیش[SEP][CLS][CLS][CLS] فردوسی[CLS][BOM]
# step   126 | loss: 4.725637 | lr 1.0657e-04 | norm: 3.2956 | dt: 6936.17ms | tok/sec: 2657.38
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که بر شاه بر اندرند[SEP][CLS][CLS] فردوسی[CLS][BOM] از[BOM] همی[SEP][CLS][CLS][BOM] که به تو و از بی
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که گفت من بر ما[SEP][CLS][CLS][BOM] به از جهان بر بر و تا و بود[SEP][CLS][CLS][CLS][BOM] به و
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو بود بودند[BOM] که که پر و شاهی[SEP][CLS][CLS][CLS][BOM] که دل[BOM] به بد اندر[SEP][CLS][CLS]
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو گفت که[SEP][CLS][CLS][BOM] که گفتان او از[SEP][CLS][CLS][BOM] بهش به بد پر[SEP][CLS][CLS][BOM]
# step   127 | loss: 4.704459 | lr 1.0741e-04 | norm: 1.5066 | dt: 6937.14ms | tok/sec: 2657.00
# validation loss: 4.7037
# rank 0 sample 0: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که گفت او[BOM] چنین‌ان باست وشند بر[SEP][CLS][CLS][CLS] فردوسی[CLS][BOM][BOM] چو پس ز راه
# rank 0 sample 1: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] که بر بد به ما[SEP][CLS][CLS][BOM] به از کاری[BOM] ز به بر که از دل[SEP][CLS][CLS][CLS] فردوسی
# rank 0 sample 2: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] چو اندر آمد یکی آن[SEP][CLS][CLS][BOM] چنین بر گفت[BOM] یکی شد اندر و داد[SEP][CLS][CLS][CLS][BOM] که بود
# rank 0 sample 3: [CLS] بهار دلکش[SEP][CLS][CLS][BOM] از گفت رای اندر را هر[SEP][CLS][CLS][BOM] همه من چونی اندر یک پیش[SEP][CLS][CLS] فردوسی[CLS][BOM] چو
# step   128 | loss: 4.708681 | lr 1.0825e-04 | norm: 2.1314 | dt: 18116.15ms | tok/sec: 1017.43
